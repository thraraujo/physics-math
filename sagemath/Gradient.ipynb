# %%
# Esse termo define as nossas coordenadas
x,y = var('x, y')

# %%
# A função que nos queremos estudar
f = 1/sqrt(x^2+y^2)

# %%
# A função que nos queremos estudar
f = ln(y*x)*cos(x*y)

# %%
contorno = show(contour_plot(f, (x, -3, 3), (y, -3, 3), fill=false))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# Gradiente da função
gr_f = f.gradient()

# %%
show(gr_f)
# Out:
# (-y*log(x*y)*sin(x*y) + cos(x*y)/x, -x*log(x*y)*sin(x*y) + cos(x*y)/y)

# %%
campo_gradiente = plot_vector_field(gr_f, (x, -0.5, 0.5), (y, -0.5, 0.5), color='purple')

# %%
show(campo_gradiente)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# Vamos plotar outro gráfico
v = (- y / (x^2 + y^2), x / (x^2 + y^2))

# %%
campo_vetorial = plot_vector_field(v, (x, -10, 10), (y, -10, 10), color='purple')

# %%
show(campo_vetorial)
# Out:
# Graphics object consisting of 1 graphics primitive

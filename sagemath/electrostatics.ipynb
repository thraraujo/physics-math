# %%
x,y,z=var('x y z')

# %%
r = (x^2 + y^2 + z^2)^(3/2)

# %%
p = plot_vector_field3d((x / r, y / r, z / r), (x,-0.5,0.5), (y,-0.5,0.5), (z,-0.5,0.5))

# %%
p.show()
# Out:
# Graphics3d Object

# %%
x,y=var('x y')

# %%
r = (x^2 + y^2)^(3/2)

# %%
p = plot_vector_field((x / r, y / r), (x,-0.5,0.5), (y,-0.5,0.5))

# %%
p.show()
# Out:
# Graphics object consisting of 1 graphics primitive
